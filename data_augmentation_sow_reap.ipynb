# %% [markdown]
# # Imports and Setups

# %%
# !git clone https://www.github.com/GEM-benchmark/NL-Augmenter
# Out:
# Cloning into 'NL-Augmenter'...
# ...
# remote: Enumerating objects: 12857, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 12857 (delta 2), reused 5 (delta 2), pack-reused 12842
# Receiving objects: 100% (12857/12857), 91.61 MiB | 16.57 MiB/s, done.
# Resolving deltas: 100% (8374/8374), done.

# %%
cd NL-Augmenter
# Out:
# /content/NL-Augmenter

# %%
# !pip install -r requirements.txt --quiet
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0.tar.gz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 88.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
! pip install sgmllib3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! pip install benepar
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for benepar: filename=benepar-0.2.0-py3-none-any.whl size=37647 sha256=b34676405ab66da404a385ca0e88f37fbc992ce74a6ab50151584360d628ae49
#   Stored in directory: /root/.cache/pip/wheels/dc/9a/8b/5d4c83fde00b8d068594afa8dd3907809f592e019423df533f
# Successfully built benepar
# ...

# %% [markdown]
# Lendo o Arquivo

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()

# %%
num_gen = 5
perc = 5

# %%
from nlaugmenter.transformations.syntactically_diverse_paraphrase.transformation  import ParaphraseSowReap

# %%
augmenter = ParaphraseSowReap(max_outputs=5)
# Out:
# ...
# .vector_cache/glove.6B.zip: 0.00B [00:00, ?B/s]
# .vector_cache/glove.6B.zip: 862MB [02:45, 5.21MB/s]
# 100%|█████████▉| 399999/400000 [00:10<00:00, 38708.87it/s]
# ...
# [nltk_data] Downloading package benepar_en3 to /root/nltk_data...
# [nltk_data]   Unzipping models/benepar_en3.zip.

# %%
augmenter.generate("Jason wants to move back to India by the end of next year.")
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/distributions/distribution.py:51: UserWarning: <class 'torch_struct.distributions.TreeCRF'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(f'{self.__class__} does not define `arg_constraints`. ' +
# ["by next year 's end , jason wants to move back .",
#  'in india by the end of next year , jason wants to move back .',
#  'by the end of next year , jason wants to move back to india .',
#  'next year , jason wants to move back to india .',
#  'next year , jason wants to move back to india .']
